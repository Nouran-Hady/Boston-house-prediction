# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor 
from sklearn import metrics
from sklearn.metrics import accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing Data

# %%
data = pd.read_csv('/kaggle/input/boston-housepredict/boston_train.csv')

# %% [markdown]
# # Exploring Data

# %%
data.describe()
# Out:
#                ID        crim          zn       indus        chas         nox  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean   250.951952    3.360341   10.689189   11.293483    0.060060    0.557144
# std    147.859438    7.352272   22.674762    6.998123    0.237956    0.114955
# min      1.000000    0.006320    0.000000    0.740000    0.000000    0.385000
# 25%    123.000000    0.078960    0.000000    5.130000    0.000000    0.453000
# 50%    244.000000    0.261690    0.000000    9.900000    0.000000    0.538000
# 75%    377.000000    3.678220   12.500000   18.100000    0.000000    0.631000
# max    506.000000   73.534100  100.000000   27.740000    1.000000    0.871000
#
#                rm         age         dis         rad         tax     ptratio  \
# count  333.000000  333.000000  333.000000  333.000000  333.000000  333.000000
# mean     6.265619   68.226426    3.709934    9.633634  409.279279   18.448048
# ...

# %%
data.columns
# Out:
# Index(['ID', 'crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad',
#        'tax', 'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 333 entries, 0 to 332
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       333 non-null    int64
#  1   crim     333 non-null    float64
#  2   zn       333 non-null    float64
#  3   indus    333 non-null    float64
#  4   chas     333 non-null    int64
#  5   nox      333 non-null    float64
#  6   rm       333 non-null    float64
#  7   age      333 non-null    float64
#  8   dis      333 non-null    float64
#  9   rad      333 non-null    int64
#  10  tax      333 non-null    int64
#  11  ptratio  333 non-null    float64
#  12  black    333 non-null    float64
#  13  lstat    333 non-null    float64
#  14  medv     333 non-null    float64
# dtypes: float64(11), int64(4)
# memory usage: 39.1 KB

# %%
plt.subplots(figsize=(20,15))
correlation_matrix = data.corr().round(2)
sns_plot=sns.heatmap(data=correlation_matrix, annot=True)

# %% [markdown]
# # Cleaning data

# %%
data.isnull().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
data.isna().sum()
# Out:
# ID         0
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# black      0
# lstat      0
# medv       0
# dtype: int64

# %%
data.drop('ID',axis=1,inplace=True)

# %% [markdown]
# # Splitting Data

# %%
X = data.drop('medv',axis=1)

# %%
X.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat'],
#       dtype='object')

# %%
Y = data['medv']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20 , random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# ****1. Linear Regression****

# %%
LR = LinearRegression()
LR.fit(X_train,y_train)
predictions = LR.predict(X_test)
m1=LR.score(X_test, y_test)

# %%
error = metrics.r2_score(y_test, predictions)
print('R squared error : ', error*100)
# Out:
# R squared error :  73.12411054098573
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[33], line 4
#       1 error = metrics.r2_score(y_test, predictions)
#       2 print('R squared error : ', error*100)
# ----> 4 print("Model Accuracy is {p}%".format(p =round (accuracy_score(y_test, m1)*100, 2)))
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 to_ignore += ["self", "cls"]
#     185 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 187 validate_parameter_constraints(
#     188     parameter_constraints, params, caller_name=func.__qualname__
#     189 )
#     191 try:
#     192     return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ****2. Random Forest Regressor****

# %%
RF = RandomForestRegressor(n_estimators=100)
RF.fit(X_train,y_train)
td_predictions = RF.predict(X_test)

# %%
error = metrics.r2_score(y_test, td_predictions) # coefficient of determination, regression score function.
print('R squared error : ', error *100)
# Out:
# R squared error :  91.35178170008545
